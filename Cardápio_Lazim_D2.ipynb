# %% [markdown]
# <a href="https://colab.research.google.com/github/LazimJunior/Cardapio/blob/main/Card%C3%A1pio_Lazim_D2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **AVALIAÇÂO A1 ESTRUTURA DE DADOS**
#
# **Aluno**: *Lazim Francisco de Oliveira Junior*
#
# **RGM**: *1434385631*
#
# **Turma**: *D2*
#
# **Turno**: *Matutino*

# %% [markdown]
# # -----------------------------------------------------------------------------------------------

# %% [markdown]
# # Importando a biblioteca pandas.

# %%
import pandas as pd

# %% [markdown]
# # Criando o dicionário: Cardapio.

# %%
Cardapio = {
}

# %% [markdown]
# # Inserindo valores ao dicionário.

# %%
Cardapio = {
    "Data": ["13/05/2024", "14/05/2024","15/05/2024","16/05/2024","17/05/2024","18/05/2024","19/05/2024"],

    "Valor calórico (Kcal)": [856,1086,832,1034,1098,1010,902],

    "Prato proteico": ["Cubos de peito de frango ao molho com batata","Dobradinha ou ovo","Frango à moda caipira (coxa e sobrecoxa cozida, tomate, cebola e quiabo)","Isca de carne acebolada","Feijoada ou Quibe assado com hortelã","Frango xadrez (peito de frango, pimentão, cebola, cenoura, repolho e shoyo)","Silverinha de carne moída"],

    "Guarnição": ["Abobrinha refogada","Farofa crocante","Polenta","Purê de batata","Farofa de couve","Macarrão ao alho e óleo","Abóbora refogada"],

    "Salada": ["Repolho e tomate","Cenoura e alface","Tomate e acelga","Beterraba e chicória","Vinagrete (tomate, pimentão, cebola, azeite e vinagre)","Pepino e tomate","Tomate e alface"],

    "Acompanhamento": ["Arroz branco e Feijão","Arroz branco e Feijão","Arroz branco e Feijão","Arroz branco e Feijão","Arroz branco e Feijão","Arroz branco e Feijão","Arroz branco e Feijão"],

    "Sobremesa": ["Laranja","Banana","Mexerica","Gelatina","Laranja","Banana","Melão"],

    "Bebida": ["Suco","Suco","Suco","Suco","Suco","Suco","Suco"]
}
print(Cardapio)
# Out:
# {'Data': ['13/05/2024', '14/05/2024', '15/05/2024', '16/05/2024', '17/05/2024', '18/05/2024', '19/05/2024'], 'Valor calórico (Kcal)': [856, 1086, 832, 1034, 1098, 1010, 902], 'Prato proteico': ['Cubos de peito de frango ao molho com batata', 'Dobradinha ou ovo', 'Frango à moda caipira (coxa e sobrecoxa cozida, tomate, cebola e quiabo)', 'Isca de carne acebolada', 'Feijoada ou Quibe assado com hortelã', 'Frango xadrez (peito de frango, pimentão, cebola, cenoura, repolho e shoyo)', 'Silverinha de carne moída'], 'Guarnição': ['Abobrinha refogada', 'Farofa crocante', 'Polenta', 'Purê de batata', 'Farofa de couve', 'Macarrão ao alho e óleo', 'Abóbora refogada'], 'Salada': ['Repolho e tomate', 'Cenoura e alface', 'Tomate e acelga', 'Beterraba e chicória', 'Vinagrete (tomate, pimentão, cebola, azeite e vinagre)', 'Pepino e tomate', 'Tomate e alface'], 'Acompanhamento': ['Arroz branco e Feijão', 'Arroz branco e Feijão', 'Arroz branco e Feijão', 'Arroz branco e Feijão', 'Arroz branco e Feijão
# ...

# %% [markdown]
# # Transformando Dicionário em DataFrame.

# %%
DF_Cardapio = pd.DataFrame(Cardapio)
display(DF_Cardapio)
# Out:
#          Data  Valor calórico (Kcal)  \
# 0  13/05/2024                    856
# 1  14/05/2024                   1086
# 2  15/05/2024                    832
# 3  16/05/2024                   1034
# 4  17/05/2024                   1098
# 5  18/05/2024                   1010
# 6  19/05/2024                    902
#
#                                       Prato proteico                Guarnição  \
# 0       Cubos de peito de frango ao molho com batata       Abobrinha refogada
# 1                                  Dobradinha ou ovo          Farofa crocante
# 2  Frango à moda caipira (coxa e sobrecoxa cozida...                  Polenta
# 3                            Isca de carne acebolada           Purê de batata
# 4               Feijoada ou Quibe assado com hortelã          Farofa de couve
# 5  Frango xadrez (peito de frango, pimentão, cebo...  Macarrão ao alho e óleo
# 6                          Silverinha de carne moída         Abóbora refogada
#
# ...

# %% [markdown]
# # QUESTÃO 1.
#
# **Apresente em tela (output) toda a base de dados.**
#
# *0,5 pontos*

# %%
"""
Questão 1
"""
display(DF_Cardapio)
# Out:
#          Data  Valor calórico (Kcal)  \
# 0  13/05/2024                    856
# 1  14/05/2024                   1086
# 2  15/05/2024                    832
# 3  16/05/2024                   1034
# 4  17/05/2024                   1098
# 5  18/05/2024                   1010
# 6  19/05/2024                    902
#
#                                       Prato proteico                Guarnição  \
# 0       Cubos de peito de frango ao molho com batata       Abobrinha refogada
# 1                                  Dobradinha ou ovo          Farofa crocante
# 2  Frango à moda caipira (coxa e sobrecoxa cozida...                  Polenta
# 3                            Isca de carne acebolada           Purê de batata
# 4               Feijoada ou Quibe assado com hortelã          Farofa de couve
# 5  Frango xadrez (peito de frango, pimentão, cebo...  Macarrão ao alho e óleo
# 6                          Silverinha de carne moída         Abóbora refogada
#
# ...

# %% [markdown]
#  Usei o método display para exibir o conteúdo do DataFrame como tabela.

# %% [markdown]
# # QUESTÃO 2.
#
# **Apresente o tamanho do seu dataframe (quantas colunas x linhas).**
#
# *0,5 pontos*

# %%
"""
Questão 2
"""

print(f'O DataFrame possui {DF_Cardapio.shape[0]} linhas e {DF_Cardapio.shape[1]} colunas.')
# Out:
# O DataFrame possui 7 linhas e 8 colunas.

# %% [markdown]
#  Usei o método .shape da biblioteca pandas para obter as dimensões (número de linhas e colunas) do DataFrame e o método print para imprimir o texto.

# %% [markdown]
# # QUESTÃO 3.
#
# **Acesse a linha (x) e apresente em tela todas as características do item.**
#
# *0,5 pontos*

# %%
"""
Questão 3
"""
print(DF_Cardapio.iloc[3])
# Out:
# Data                                  16/05/2024
# Valor calórico (Kcal)                       1034
# Prato proteico           Isca de carne acebolada
# Guarnição                         Purê de batata
# Salada                      Beterraba e chicória
# Acompanhamento             Arroz branco e Feijão
# Sobremesa                               Gelatina
# Bebida                                      Suco
# Name: 3, dtype: object

# %% [markdown]
#  Usei o método .iloc da biblioteca pandas para obter os valores da linha especificada no DataFrame e o método print para exibir.

# %% [markdown]
# # QUESTÃO 4.
#
# **Verifique se o dataframe está vazio.**
#
# *0,5 pontos*

# %%
"""
Questão 4
"""

if DF_Cardapio.empty:
    print("O DataFrame está vazio.")
else:
    print("O DataFrame não está vazio.")
# Out:
# O DataFrame não está vazio.

# %% [markdown]
#  Verifiquei se o DataFrame está vazio usando a estrutura condicional IF e ELSE, juntamente com o método .empty da biblioteca pandas.
#  Depois da verificação usei o método print para exibir.

# %% [markdown]
# # QUESTÃO 5.
#
# **Apresente em tela os 5 primeiros registros da base de dados**
#
# *0,5 pontos*

# %%
"""
Questão 5
"""
display(DF_Cardapio.head(6))
# Out:
#          Data  Valor calórico (Kcal)  \
# 0  13/05/2024                    856
# 1  14/05/2024                   1086
# 2  15/05/2024                    832
# 3  16/05/2024                   1034
# 4  17/05/2024                   1098
# 5  18/05/2024                   1010
#
#                                       Prato proteico                Guarnição  \
# 0       Cubos de peito de frango ao molho com batata       Abobrinha refogada
# 1                                  Dobradinha ou ovo          Farofa crocante
# 2  Frango à moda caipira (coxa e sobrecoxa cozida...                  Polenta
# 3                            Isca de carne acebolada           Purê de batata
# 4               Feijoada ou Quibe assado com hortelã          Farofa de couve
# 5  Frango xadrez (peito de frango, pimentão, cebo...  Macarrão ao alho e óleo
#
#                                               Salada         Acompanhamento  \
# ...

# %% [markdown]
#  Usei o método .head da biblioteca pandas para exibir os 5 primeiros registros (linhas) do DataFrame e depois usei o método display para exibir como tabela.

# %% [markdown]
# # QUESTÃO 6.
#
# **Exclua um item (linha) de sua base de dados.**
#
# *0,5 pontos*

# %%
"""
Questão 6
"""

DF_Cardapio = DF_Cardapio.drop(6)
display(DF_Cardapio)
# Out:
#          Data  Valor calórico (Kcal)  \
# 0  13/05/2024                    856
# 1  14/05/2024                   1086
# 2  15/05/2024                    832
# 3  16/05/2024                   1034
# 4  17/05/2024                   1098
# 5  18/05/2024                   1010
#
#                                       Prato proteico                Guarnição  \
# 0       Cubos de peito de frango ao molho com batata       Abobrinha refogada
# 1                                  Dobradinha ou ovo          Farofa crocante
# 2  Frango à moda caipira (coxa e sobrecoxa cozida...                  Polenta
# 3                            Isca de carne acebolada           Purê de batata
# 4               Feijoada ou Quibe assado com hortelã          Farofa de couve
# 5  Frango xadrez (peito de frango, pimentão, cebo...  Macarrão ao alho e óleo
#
#                                               Salada         Acompanhamento  \
# ...

# %% [markdown]
#  Usei o método .drop para remover um item específico do DataFrame e o método display para exibir.

# %% [markdown]
# # QUESTÃO 7.
#
# **Adicione um item (linha) na sua base de dados.**
#
# *0,5 pontos*

# %%
"""
Questão 7
"""
inserir = {
    "Data": "19/05/2024",
    "Valor calórico (Kcal)": 902,
    "Prato proteico": "Silverinha de carne moída",
    "Guarnição": "Abóbora refogada",
    "Salada": "Tomate e alface",
    "Acompanhamento": "Arroz branco e Feijão",
    "Sobremesa": "Melão",
    "Bebida": "Suco",
}


linha_nova = pd.DataFrame(inserir, index=[0])

DF_Cardapio = pd.concat([DF_Cardapio, linha_nova], ignore_index=True)
display(DF_Cardapio)
# Out:
#          Data  Valor calórico (Kcal)  \
# 0  13/05/2024                    856
# 1  14/05/2024                   1086
# 2  15/05/2024                    832
# 3  16/05/2024                   1034
# 4  17/05/2024                   1098
# 5  18/05/2024                   1010
# 6  19/05/2024                    902
#
#                                       Prato proteico                Guarnição  \
# 0       Cubos de peito de frango ao molho com batata       Abobrinha refogada
# 1                                  Dobradinha ou ovo          Farofa crocante
# 2  Frango à moda caipira (coxa e sobrecoxa cozida...                  Polenta
# 3                            Isca de carne acebolada           Purê de batata
# 4               Feijoada ou Quibe assado com hortelã          Farofa de couve
# 5  Frango xadrez (peito de frango, pimentão, cebo...  Macarrão ao alho e óleo
# 6                          Silverinha de carne moída         Abóbora refogada
#
# ...

# %% [markdown]
#  Adicionei uma nova linha ao DataFrame "Cardapio":
#
#  1. Criei um novo dicionário com os dados da nova linha.
#
#  2. Converti o dicionário em um DataFrame.
#
#  3. Adicionei a nova linha ao DataFrame "Cardapio" usando o método .concat.
#
#  4. Exibi o DataFrame como tabela usando o método display.

# %% [markdown]
# # QUESTÃO 8.
#
# **Transponha a coluna para a linha em sua base de dados.**
#
# *0,5 pontos*

# %%
"""
Questão 8
"""

DF_Cardapio_transposto = DF_Cardapio.transpose()
display(DF_Cardapio_transposto)
# Out:
#                                                                   0  \
# Data                                                     13/05/2024
# Valor calórico (Kcal)                                           856
# Prato proteico         Cubos de peito de frango ao molho com batata
# Guarnição                                        Abobrinha refogada
# Salada                                             Repolho e tomate
# Acompanhamento                                Arroz branco e Feijão
# Sobremesa                                                   Laranja
# Bebida                                                         Suco
#
#                                            1  \
# Data                              14/05/2024
# Valor calórico (Kcal)                   1086
# Prato proteico             Dobradinha ou ovo
# Guarnição                    Farofa crocante
# Salada                      Cenoura e alface
# Acompanhamento         Arroz branco e Feijão
# ...

# %% [markdown]
#  Apliquei o método .transpose() ao DataFrame "Cardapio" e atribuí o resultado a uma variável e exibi o conteúdo como tabela e usando o método display.

# %% [markdown]
# # QUESTÃO 9.
#
# **Apresente em tela somente a 1ª e a 2ª coluna (rótulo) da base de dados.**
#
# *0,5 pontos*

# %%
"""
Questão 9
"""


display(DF_Cardapio.iloc[:, :2])
# Out:
#          Data  Valor calórico (Kcal)
# 0  13/05/2024                    856
# 1  14/05/2024                   1086
# 2  15/05/2024                    832
# 3  16/05/2024                   1034
# 4  17/05/2024                   1098
# 5  18/05/2024                   1010
# 6  19/05/2024                    902

# %% [markdown]
#  Usei o método .iloc da biblioteca pandas para obter um intervalo de colunas específico do DataFrame e exibido como tabela com o método display

# %% [markdown]
# # QUESTÃO 10.
#
# **Informe como foi desenvolvido o Projeto.**
#
# *0,5 pontos*

# %%
"""
Questão 10
"""
print("O meu projeto, decidi pega o cardápio semanal de almoço dos restaurantes comunitários do DF do mês de maio. me interessei por esse tema por conta da diversidade diária dos pratos e pelo preço.")
print("Coletei os dados necessários para o projeto diretamente do cardápio disponível no site do GDF e usei a biblioteca pandas para utilizar os métodos necessários.")
print("A minha principal dificuldade foi em comentar os trechos de código em que ultilizai o pandas. Mesmo tendo essa dificuldade em comentar,")
print("estou bastante satisfeito com o progresso que fiz no domínio da linguagem Python e suas bibliotecas.")
# Out:
# O meu projeto, decidi pega o cardápio semanal de almoço dos restaurantes comunitários do DF do mês de maio. me interessei por esse tema por conta da diversidade diária dos pratos e pelo preço.
# Coletei os dados necessários para o projeto diretamente do cardápio disponível no site do GDF e usei a biblioteca pandas para utilizar os métodos necessários.
# A minha principal dificuldade foi em comentar os trechos de código em que ultilizai o pandas. Mesmo tendo essa dificuldade em comentar,
# estou bastante satisfeito com o progresso que fiz no domínio da linguagem Python e suas bibliotecas.

# %% [markdown]
# Fontes:
# https://www.sedes.df.gov.br/cardapio-dos-restaurantes-comunitarios/ e https://pandas.pydata.org/docs/

# %% [markdown]
# # *********************************************************************************************
